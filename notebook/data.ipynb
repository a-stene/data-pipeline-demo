# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))
import yfinance as yf
import pandas as pd
from src.pipeline import fetch_stock_data

# %%
fetch_stock_data('NOVO-B.CO','2023-01-01','2025-01-01')
# Out:
# c:\Users\Aksel\Documents\data-pipeline-demo\src\pipeline.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Price        Date       Close        High         Low        Open    Volume
# Ticker              NOVO-B.CO   NOVO-B.CO   NOVO-B.CO   NOVO-B.CO NOVO-B.CO
# 0      2023-01-02  447.195709  449.664311  445.581615  446.578566   1301252
# 1      2023-01-03  459.681091  461.959790  448.857252  449.664299   3071214
# 2      2023-01-04  456.215607  463.478971  454.601513  460.013447   3478626
# 3      2023-01-05  455.123718  456.547908  451.088513  455.788323   2339966
# 4      2023-01-06  459.301300  461.200220  454.696413  455.930728   2142522
# ..            ...         ...         ...         ...         ...       ...
# 495    2024-12-19  722.536011  748.590849  718.161129  739.063341   2911957
# ...
